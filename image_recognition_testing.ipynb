# %% [markdown]
# <a href="https://colab.research.google.com/github/udayr2809/Image-Recognition/blob/main/image_recognition_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    '/content/drive/MyDrive/Dataset/archive/test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(64, 64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 377 files belonging to 36 classes.

# %%
cnn = tf.keras.models.load_model('/content/drive/MyDrive/Dataset/archive/model/trained_model.h5')

# %%
import cv2
image_path = '/content/drive/MyDrive/Dataset/archive/test images/imagetest1.jpg'

img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 201ms/step

# %%
print(predictions)
# Out:
# [[2.1589433e-03 7.5772260e-09 1.5449923e-03 2.4424798e-03 9.5729556e-06
#   1.0865537e-08 3.1366428e-05 3.5244270e-04 5.9296057e-04 5.8043724e-07
#   4.8675281e-07 1.6608696e-04 2.4232366e-05 2.7485551e-06 5.5663845e-06
#   4.5084143e-06 4.9445528e-04 8.8108070e-03 7.6629709e-05 1.2922451e-01
#   4.5080385e-05 4.9136201e-04 8.1826793e-06 2.3761041e-04 4.0478878e-02
#   3.3634201e-01 3.3824285e-04 6.3346676e-03 7.7930599e-04 2.9092962e-01
#   1.3691613e-04 2.3988795e-07 7.2492830e-02 8.1556609e-06 6.8049654e-02
#   3.7383970e-02]]

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 25

# %%
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
print("It's a {}".format(test_set.class_names[result_index]))
# Out:
# It's a pineapple
