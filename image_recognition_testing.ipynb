# %% [markdown]
# <a href="https://colab.research.google.com/github/udayr2809/Image-Recognition/blob/main/image_recognition_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    '/content/drive/MyDrive/Dataset/archive/test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(64, 64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 377 files belonging to 36 classes.

# %%
cnn = tf.keras.models.load_model('/content/drive/MyDrive/Dataset/archive/model/trained_model.h5')

# %%
image_path = '/content/drive/MyDrive/Dataset/archive/test images/imagetest2.jpg'
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
print(predictions)
# Out:
# [[8.36518842e-13 9.99892235e-01 3.95560562e-09 7.45743477e-15
#   5.18840714e-14 8.84454609e-15 2.56111868e-11 1.45700639e-11
#   4.89391618e-11 1.02487764e-04 1.38968725e-13 2.02552895e-18
#   5.46920311e-13 3.62733443e-09 2.89848421e-17 5.33415534e-11
#   3.07888304e-17 2.03791572e-07 4.96610970e-16 1.02492050e-08
#   2.31898922e-09 6.92006999e-12 3.69767591e-14 4.02727721e-07
#   8.61797293e-22 1.85488052e-14 4.24895314e-24 4.46386230e-06
#   3.71302349e-08 3.68965932e-21 6.35624647e-20 8.20577455e-08
#   2.12386651e-14 4.31190926e-19 1.23322940e-14 1.44216293e-17]]

# %%
result_index = np.argmax(predictions)
print(result_index)
# Out:
# 1

# %%
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
print("It's a {}".format(test_set.class_names[result_index]))
# Out:
# It's a banana
